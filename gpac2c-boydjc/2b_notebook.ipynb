# %% [markdown]
# # Assignment 2b Notebook: Automated Design of AI Agents with Genetic Programming
# In this assignment, you will further iterate on to your Assignment 2a implementation of random parse tree generation to realize a full genetic programming (GP) implementation. Like Assignment Series 1, you will leverage components you've already implemented in this assignment. From your previous assignment implementations, copy over the following files:
# * base_evolution.py
# * selection.py
# * tree_genotype.py
#
# As usual, be careful not to overwrite any of the provided files that may have been modified since previous assignments. To begin the assignment, execute the following cell. **If you implemented your genotype in a new file, be sure to import it in the next cell!**

# %%
# Configure this notebook to automatically reload modules as they're modified
# https://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
from snake_eyes import read_config
from fitness import play_GPac
from selection import *
from tree_genotype import *
from parse_tree import *

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12.0, 12.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

print('The first cell has been executed!')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The first cell has been executed!

# %% [markdown]
# ## Recombination
# Assuming you've correctly implemented population initialization in Assignment 2a, we'll begin this assignment by implementing recombination with subtree crossover. Like Assignment Series 1, your recombination method should take a mate as input and recombine the genes of `self` and `mate`, assign the recombination to the `gene` member variable of `child` and then return child. Recall that you should somehow enforce a configurable maximum tree depth throughout this assignment and this applies to children produced with recombination and mutation.
#
# How you implement subtree crossover in practice depends on your implementation of the parse tree gene and is thus open-ended. Implement `TreeGenotype.recombine` and test your implementation by executing the following cell.

# %%
import random

# read config
config = read_config('./configs/green2b_config.txt', globalVars=globals(), localVars=locals())

# initialize population
random_population = TreeGenotype.initialization(25, **config['initialization_kwargs'])

# perform recombination
children = list()
for idx in range(len(random_population)):
    child = random_population[idx].recombine(random_population[(idx+1)%len(random_population)],
                                             **config['recombination_kwargs'])


    children.append(child)


# print recombined trees to files
for idx, individual in enumerate(children):
    with open(f'treeTests/tree{idx}r.txt','w') as f:
        f.write(individual.print())
            
del random_population, children, config

# evaluate tree files
# !python tree_check.py treeTests/tree*r.txt
# Out:
# treeTests/tree0r.txt: PASS
# treeTests/tree10r.txt: PASS
# treeTests/tree11r.txt: PASS
# treeTests/tree12r.txt: PASS
# treeTests/tree13r.txt: PASS
# treeTests/tree14r.txt: PASS
# treeTests/tree15r.txt: PASS
# treeTests/tree16r.txt: PASS
# treeTests/tree17r.txt: PASS
# treeTests/tree18r.txt: PASS
# treeTests/tree19r.txt: PASS
# treeTests/tree1r.txt: PASS
# treeTests/tree20r.txt: PASS
# treeTests/tree21r.txt: PASS
# treeTests/tree22r.txt: PASS
# treeTests/tree23r.txt: PASS
# treeTests/tree24r.txt: PASS
# treeTests/tree2r.txt: PASS
# treeTests/tree3r.txt: PASS
# treeTests/tree4r.txt: PASS
# treeTests/tree5r.txt: PASS
# treeTests/tree6r.txt: PASS
# treeTests/tree7r.txt: PASS
# treeTests/tree8r.txt: PASS
# treeTests/tree9r.txt: PASS

# %% [markdown]
# ## Mutation
# Recall that mutation in GP is mutually exclusive with recombination. That is to say that mutation in GP is used to directly produce children by mutating a copy of the parent.
#
# Using your parse tree gene implementation, implement subtree mutation in `TreeGenotype.mutate` and test your implementation by executing the next cell. Don't forget to enforce max tree depth like in recombination!

# %%
# read config
config = read_config('./configs/green2b_config.txt', globalVars=globals(), localVars=locals())

# initialize population
random_population = TreeGenotype.initialization(25, **config['initialization_kwargs'])

# perform mutation
children = list()
for individual in random_population:
    children.append(individual.mutate(**config['mutation_kwargs']))

# print mutated trees to files
for idx, individual in enumerate(children):
    with open(f'treeTests/tree{idx}m.txt','w') as f:
        f.write(individual.print())
del random_population, children, config

# evaluate tree files
# !python tree_check.py treeTests/tree*m.txt
# Out:
# treeTests/tree0m.txt: PASS
# treeTests/tree10m.txt: PASS
# treeTests/tree11m.txt: PASS
# treeTests/tree12m.txt: PASS
# treeTests/tree13m.txt: PASS
# treeTests/tree14m.txt: PASS
# treeTests/tree15m.txt: PASS
# treeTests/tree16m.txt: PASS
# treeTests/tree17m.txt: PASS
# treeTests/tree18m.txt: PASS
# treeTests/tree19m.txt: PASS
# treeTests/tree1m.txt: PASS
# treeTests/tree20m.txt: PASS
# treeTests/tree21m.txt: PASS
# treeTests/tree22m.txt: PASS
# treeTests/tree23m.txt: PASS
# treeTests/tree24m.txt: PASS
# treeTests/tree2m.txt: PASS
# treeTests/tree3m.txt: PASS
# treeTests/tree4m.txt: PASS
# treeTests/tree5m.txt: PASS
# treeTests/tree6m.txt: PASS
# treeTests/tree7m.txt: PASS
# treeTests/tree8m.txt: PASS
# treeTests/tree9m.txt: PASS

# %% [markdown]
# ## Implementing Genetic Programming
# By this point, you should have a complete implementation of your genotype and we can turn our attention to implementing the complete GP algorithm.
#
# ### Evaluation and Parsimony Pressure
# Recall from the lecture and videos by Dr. Koza that GP tends to produce individual genotypes of increasing size without a mechanism to curb this. You will implement a parsimony penalty to encourage your GP to produce more compact trees (in addition to the depth limits you already have). With this mechanism of parsimony pressure, you will penalize the fitness of a solution based on their size. $fitness(i)=raw\_fitness(i)-C_p*size(i)$ where $C_p$ is a parsimony coefficient from your config file and $size(i)$ is a function that returns the size of individual $i$. The two most obvious metrics of tree size are tree depth and node count, but you are encouraged with experiments to use the size metric that performs best.
#
# **Note**: The implementation of a parsimony penalty is nearly identical to the penalty-based constraint satisfaction method you implemented in Assignment 1c. Like Assignment 1c, *it is not meaningful to compare penalized fitness with unpenalized fitness* and we require that you use penalized fitness for evolution and raw fitness for analysis.
#
# In the file `gpac_population_evaluation.py`, implement the `basic_population_evaluation` function that performs fitness evaluations on an input population using the input configuration parameters and assigns parsimony-penalized fitness, raw fitness, and saves the log of the fitness evaluation. Now test your implementation by executing the following cell.

# %%
from gpac_population_evaluation import basic_population_evaluation
import statistics

config = read_config('./configs/green2b_config.txt', globalVars=globals(), localVars=locals())

example_population = TreeGenotype.initialization(25, **config['initialization_kwargs'])
for individual in example_population:
    individual.raw_fitness = None
    individual.log = None

# calling your function to test things out (this function is called the same as in notebook 1c)
basic_population_evaluation(example_population, **config['fitness_kwargs'])

missing = len([True for individual in example_population if individual.fitness is None])
print(f'Individuals with unassigned (penalized) fitness: {missing}')
raw_missing = len([True for individual in example_population if individual.raw_fitness is None])
print(f'Individuals with unassigned raw fitness: {raw_missing}')
print(f'Number of complete fitness evaluations performed: {len(example_population) - max(missing, raw_missing)}')
if missing == 0 and raw_missing == 0:
    fitnesses = [individual.fitness for individual in example_population]
    print(f'Average fitness of population: {statistics.mean(fitnesses)}')
    print(f'Best fitness in population: {max(fitnesses)}')
    raw_fitnesses = [individual.raw_fitness for individual in example_population]
    print(f'Average raw fitness of population: {statistics.mean(raw_fitnesses)}')
    print(f'Best unpenalized (raw) fitness in population: {max(raw_fitnesses)}')
    best_log = max(example_population, key=lambda ind: ind.fitness).log

    print(f'Found log of highest scoring individual? {best_log is not None}')
    game_log_path = 'worldFiles/testParsimony.txt'
    with open(game_log_path, 'w') as f:
        [f.write(f'{line}\n') for line in best_log]

    print(f"The log of the most fit individual was written to {game_log_path}")
else:
    print('Ensure the entire population is evaluated then execute this cell again')

del example_population, config
# Out:
# Individuals with unassigned (penalized) fitness: 0
# Individuals with unassigned raw fitness: 0
# Number of complete fitness evaluations performed: 25
# Average fitness of population: -815.96
# Best fitness in population: 8
# Average raw fitness of population: 9.44
# Best unpenalized (raw) fitness in population: 53
# Found log of highest scoring individual? True
# The log of the most fit individual was written to worldFiles/testParsimony.txt

# %% [markdown]
# ### Child Generation
# With fitness evaluation implemented, we can now perform parent selection and move to implementing child generation with the `GeneticProgrammingPopulation` class. This class inherits the `BaseEvolutionPopulation` class from last assignment and should be able to directly use the inherited initialization and survival selection methods without modification. Child generation is different in GP, as mentioned previously in this notebook, so you need to implement the GP version of `generate_children` in the `GeneticProgrammingPopulation` class. Once complete, test your implementation in the following cell.

# %%
from genetic_programming import *

config = read_config('./configs/green2b_config.txt', globalVars=globals(), localVars=locals())

# full initialization of your GP population
example_EA = GeneticProgrammingPopulation(**config['EA_configs'], **config)
basic_population_evaluation(example_EA.population, **config['fitness_kwargs'])
example_EA.evaluations = len(example_EA.population)
fitnesses = [individual.fitness for individual in example_EA.population]
print(f'Average fitness of population: {statistics.mean(fitnesses)}')
print(f'Best fitness in population: {max(fitnesses)}')
print(f'Number of fitness evaluations: {example_EA.evaluations}')

# generate children
children = example_EA.generate_children()
basic_population_evaluation(children, **config['fitness_kwargs'])
example_EA.evaluations += len(children)
children_fitnesses = [individual.fitness for individual in children]
print(f'Average fitness of children: {statistics.mean(children_fitnesses)}')
print(f'Best fitness of children: {max(children_fitnesses)}')
print(f'Number of fitness evaluations: {example_EA.evaluations}')

# print children trees to files
for idx, individual in enumerate(children):
    with open(f'treeTests/tree{idx}c.txt','w') as f:
        f.write(individual.print())
del example_EA, children, config, fitnesses, children_fitnesses

# evaluate tree files
# !python tree_check.py treeTests/tree*c.txt
# Out:
# Average fitness of population: -816.38
# Best fitness in population: 1
# Number of fitness evaluations: 50
# Average fitness of children: -5
# Best fitness of children: -5
# Number of fitness evaluations: 57
# treeTests/tree0c.txt: PASS
# treeTests/tree1c.txt: PASS
# treeTests/tree2c.txt: PASS
# treeTests/tree3c.txt: PASS
# treeTests/tree4c.txt: PASS
# treeTests/tree5c.txt: PASS
# treeTests/tree6c.txt: PASS

# %% [markdown]
# ## Single Run Experiment
# At this point, you should have implemented the full GP algorithm to evolve GPac controllers! Now put all the components together and implement a single-run experiment with 2,000 fitness evaluations in the next cells.

# %%
from math import inf

# implement your GP here
def genetic_programming_search(number_evaluations, config_filename, run_number):
    best_fitness = -inf
    best_log = None
    best_tree = None
    data = []
    
    # Parse the config and implement your EA here.
    # Feel free to focus on implementation first and then return for data collection.
    
    config = read_config(config_filename, globalVars=globals(), localVars=locals())

    # full initialization of your GP population
    example_EA = GeneticProgrammingPopulation(**config['EA_configs'], **config)
    basic_population_evaluation(example_EA.population, **config['fitness_kwargs'])
    example_EA.evaluations = len(example_EA.population)
    fitnesses = [individual.fitness for individual in example_EA.population]
    
    data.append([statistics.mean(fitnesses), max(fitnesses)])
    
    # i've just been changing this for the different deliverable runs
    # instead of having multiple GP search functions that are basically the same
    if('green' in config_filename):
        with open('./data/green/run' + str(run_number) + 'Data.txt', 'w') as fp:
            fp.write(f'Number of Evaluations: {example_EA.evaluations}\n')
            fp.write(f'Best Fitness: {max(fitnesses)}\n')
            fp.write(f'Average Fitness: {statistics.mean(fitnesses)}\n')
            fp.write('------------------------\n')
    elif('yellow' in config_filename):
        with open('./data/yellow/depth_parsimony/run' + str(run_number) + 'Data.txt', 'w') as fp:
            fp.write(f'Number of Evaluations: {example_EA.evaluations}\n')
            fp.write(f'Best Fitness: {max(fitnesses)}\n')
            fp.write(f'Average Fitness: {statistics.mean(fitnesses)}\n')
            fp.write('------------------------\n')
    elif('red1' in config_filename):
        with open('./data/redOne/run' + str(run_number) + 'Data.txt', 'w') as fp:
            fp.write(f'Number of Evaluations: {example_EA.evaluations}\n')
            fp.write(f'Best Fitness: {max(fitnesses)}\n')
            fp.write(f'Average Fitness: {statistics.mean(fitnesses)}\n')
            fp.write('------------------------\n')
    
    #print(f'Average fitness of population: {statistics.mean(fitnesses)}')
    #print(f'Best fitness in population: {max(fitnesses)}')
    #print(f'Number of fitness evaluations: {example_EA.evaluations}')
    
    while not(example_EA.evaluations >= number_evaluations):
        
        # generate children
        children = example_EA.generate_children()
        basic_population_evaluation(children, **config['fitness_kwargs'])
        example_EA.evaluations += len(children)
        children_fitnesses = [individual.fitness for individual in children]
        
        if(max(children_fitnesses) > best_fitness):
            best_fitness = max(children_fitnesses)
            best_log = children[children_fitnesses.index(best_fitness)].log
            best_tree = children[children_fitnesses.index(best_fitness)]
            #print(f'\tNew best fitness: {best_fitness}')
            #print(f'\tRaw Fitness: {best_tree.raw_fitness}')
        
        data.append([statistics.mean(children_fitnesses), max(children_fitnesses)])
        
        if('green' in config_filename):
            with open('./data/green/run' + str(run_number) + 'Data.txt', 'a') as fp:
                fp.write(f'Number of Evaluations: {example_EA.evaluations}\n')
                fp.write(f'Best Fitness: {max(children_fitnesses)}\n')
                fp.write(f'Average Fitness: {statistics.mean(children_fitnesses)}\n')
                fp.write('------------------------\n')
        elif('yellow' in config_filename):
             with open('./data/yellow/depth_parsimony/run' + str(run_number) + 'Data.txt', 'w') as fp:
                fp.write(f'Number of Evaluations: {example_EA.evaluations}\n')
                fp.write(f'Best Fitness: {max(fitnesses)}\n')
                fp.write(f'Average Fitness: {statistics.mean(fitnesses)}\n')
                fp.write('------------------------\n')
        elif('red1' in config_filename):
            with open('./data/redOne/run' + str(run_number) + 'Data.txt', 'w') as fp:
                fp.write(f'Number of Evaluations: {example_EA.evaluations}\n')
                fp.write(f'Best Fitness: {max(fitnesses)}\n')
                fp.write(f'Average Fitness: {statistics.mean(fitnesses)}\n')
                fp.write('------------------------\n')
        
        
        #print(f'Average fitness of population: {statistics.mean(children_fitnesses)}')
        #print(f'Best fitness in population: {max(children_fitnesses)}')
        #print(f'Number of fitness evaluations: {example_EA.evaluations}')
        #print('-------------------')
            
    #game_log_path = 'worldFiles/testSingleRun.txt'
    #with open(game_log_path, 'w') as f:
    #    [f.write(f'{line}\n') for line in best_log]
        
    #print('Best Tree')
    #print(best_tree.print())
    
    overallAverageFitness = statistics.mean([gen[0] for gen in data])
    overallAverageBestFitness = statistics.mean([gen[1] for gen in data])
    
    return best_fitness, best_log, best_tree, overallAverageFitness, overallAverageBestFitness

# %%
# testing your implementation out
genetic_programming_search(2000, './configs/green2b_config.txt', 0)
# Out:
# (81,
#  ['35',
#   '20',
#   'm 0 19',
#   '0 34 0',
#   '1 34 0',
#   '2 34 0',
#   'w 0 5',
#   'w 0 6',
#   'w 0 7',
#   'w 0 8',
#   'w 1 1',
#   'w 1 2',
#   'w 1 3',
#   'w 1 10',
#   'w 1 11',
#   'w 1 12',
#   'w 1 13',
#   'w 1 15',
#   'w 1 17',
#   'w 1 18',
#   'w 2 1',
#   'w 2 5',
#   'w 2 6',
#   'w 2 7',
#   'w 2 8',
#   'w 2 13',
#   'w 2 15',
#   'w 2 17',
#   'w 2 18',
#   'w 3 1',
#   'w 3 3',
#   'w 3 4',
#   'w 3 5',
#   'w 3 6',
#   'w 3 7',
#   'w 3 8',
#   'w 3 9',
#   'w 3 10',
#   'w 3 11',
#   'w 3 13',
#   'w 3 17',
#   'w 3 18',
#   'w 4 3',
#   'w 4 4',
#   'w 4 5',
#   'w 4 6',
#   'w 4 7',
#   'w 4 8',
#   'w 4 9',
#   'w 4 10',
#   'w 4 11',
#   'w 4 15',
#   'w 5 1',
#   'w 5 2',
#   'w 5 3',
#   'w 5 4',
#   'w 5 5',
#   'w 5 6',
#   'w 5 7',
#   'w 5 8',
#   'w 5 9',
#   'w 5 10',
#   'w 5 11',
#   'w 5 12',
#   'w 5 14',
#   'w 5 15',
#   'w 5 16',
#   'w 5 18',
#   'w 6 3',
#   'w 6 4',
#   'w 6 5',
#   'w 6 6',
#   'w 6 7',
#   'w 6 8',
#   'w 6 9',
#   'w 6 10',
#   'w 6 11',
#   'w 6 12',
#   'w 6 14',
#   'w 6 15',
#   'w 6 16',
#   'w 6 18',
#   'w 7 1',
#   'w 7 3',
#   'w 7 4',
#   'w 7 5',
#   'w 7 6',
#   'w 7 7',
#   'w 7 8',
#   'w 7 9',
#   'w 7 14',
#   'w 7 15',
#   'w 7 16',
#   'w 8 3',
#   'w 8 4',
#   'w 8 5',
#   'w 8 6',
#   'w 8 7',
#   'w 8 8',
#   'w 8 9',
#   'w 8 11',
#   'w 8 12',
#   'w 8 13',
#   'w 8 14',
#   'w 8 15',
#   'w 8 16',
#   'w 8 18',
#   'w 9 0',
#   'w 9 2',
#   'w 9 3',
#   'w 9 4',
#   'w 9 5',
#   'w 9 6',
#   'w 9 7',
#   'w 9 8',
#   'w 9 9',
#   'w 9 11',
#   'w 9 12',
#   'w 9 13',
#   'w 9 14',
#   'w 9 15',
#   'w 9 16',
#   'w 10 0',
#   'w 10 2',
#   'w 10 3',
#   'w 10 4',
#   'w 10 5',
#   'w 10 6',
#   'w 10 7',
#   'w 10 8',
#   'w 10 9',
#   'w 10 11',
#   'w 10 12',
#   'w 10 13',
#   'w 10 14',
#   'w 10 15',
#   'w 10 16',
#   'w 10 17',
#   'w 10 18',
#   'w 11 0',
#   'w 11 2',
#   'w 11 3',
#   'w 11 4',
#   'w 11 5',
#   'w 11 6',
#   'w 11 7',
#   'w 11 8',
#   'w 11 9',
#   'w 11 11',
#   'w 11 12',
#   'w 11 13',
#   'w 11 14',
#   'w 11 15',
#   'w 11 16',
#   'w 11 17',
#   'w 11 18',
#   'w 12 2',
#   'w 12 3',
#   'w 12 4',
#   'w 12 5',
#   'w 12 11',
#   'w 12 12',
#   'w 12 13',
#   'w 12 14',
#   'w 12 15',
#   'w 12 16',
#   'w 12 17',
#   'w 12 18',
#   'w 13 1',
#   'w 13 2',
#   'w 13 3',
#   'w 13 4',
#   'w 13 5',
#   'w 13 7',
#   'w 13 8',
#   'w 13 9',
#   'w 14 1',
#   'w 14 2',
#   'w 14 3',
#   'w 14 4',
#   'w 14 5',
#   'w 14 7',
#   'w 14 8',
#   'w 14 9',
#   'w 14 11',
#   'w 14 13',
#   'w 14 14',
#   'w 14 15',
#   'w 14 16',
#   'w 14 17',
#   'w 14 18',
#   'w 15 7',
#   'w 15 8',
#   'w 15 9',
#   'w 15 11',
#   'w 16 1',
#   'w 16 2',
#   'w 16 3',
#   'w 16 4',
#   'w 16 13',
#   'w 16 14',
#   'w 16 15',
#   'w 16 17',
#   'w 16 18',
#   'w 16 19',
#   'w 17 1',
#   'w 17 2',
#   'w 17 3',
#   'w 17 4',
#   'w 17 6',
#   'w 17 7',
#   'w 17 8',
#   'w 17 9',
#   'w 17 10',
#   'w 17 11',
#   'w 17 13',
#   'w 17 14',
#   'w 17 15',
#   'w 17 17',
#   'w 17 18',
#   'w 17 19',
#   'w 18 1',
#   'w 18 2',
#   'w 18 3',
#   'w 18 4',
#   'w 18 13',
#   'w 18 14',
#   'w 18 15',
#   'w 18 17',
#   'w 18 18',
#   'w 18 19',
#   'w 19 7',
#   'w 19 8',
#   'w 19 9',
#   'w 19 11',
#   'w 20 1',
#   'w 20 2',
#   'w 20 3',
#   'w 20 4',
#   'w 20 5',
#   'w 20 7',
#   'w 20 8',
#   'w 20 9',
#   'w 20 11',
#   'w 20 13',
#   'w 20 14',
#   'w 20 15',
#   'w 20 16',
#   'w 20 17',
#   'w 20 18',
#   'w 21 1',
#   'w 21 2',
#   'w 21 3',
#   'w 21 4',
#   'w 21 5',
#   'w 21 7',
#   'w 21 8',
#   'w 21 9',
#   'w 22 2',
#   'w 22 3',
#   'w 22 4',
#   'w 22 5',
#   'w 22 11',
#   'w 22 12',
#   'w 22 13',
#   'w 22 14',
#   'w 22 15',
#   'w 22 16',
#   'w 22 17',
#   'w 22 18',
#   'w 23 0',
#   'w 23 2',
#   'w 23 3',
#   'w 23 4',
#   'w 23 5',
#   'w 23 6',
#   'w 23 7',
#   'w 23 8',
#   'w 23 9',
#   'w 23 11',
#   'w 23 12',
#   'w 23 13',
#   'w 23 14',
#   'w 23 15',
#   'w 23 16',
#   'w 23 17',
#   'w 23 18',
#   'w 24 0',
#   'w 24 2',
#   'w 24 3',
#   'w 24 4',
#   'w 24 5',
#   'w 24 6',
#   'w 24 7',
#   'w 24 8',
#   'w 24 9',
#   'w 24 11',
#   'w 24 12',
#   'w 24 13',
#   'w 24 14',
#   'w 24 15',
#   'w 24 16',
#   'w 24 17',
#   'w 24 18',
#   'w 25 0',
#   'w 25 2',
#   'w 25 3',
#   'w 25 4',
#   'w 25 5',
#   'w 25 6',
#   'w 25 7',
#   'w 25 8',
#   'w 25 9',
#   'w 25 11',
#   'w 25 12',
#   'w 25 13',
#   'w 25 14',
#   'w 25 15',
#   'w 25 16',
#   'w 26 3',
#   'w 26 4',
#   'w 26 5',
#   'w 26 6',
#   'w 26 7',
#   'w 26 8',
#   'w 26 9',
#   'w 26 11',
#   'w 26 12',
#   'w 26 13',
#   'w 26 14',
#   'w 26 15',
#   'w 26 16',
#   'w 26 18',
#   'w 27 1',
#   'w 27 3',
#   'w 27 4',
#   'w 27 5',
#   'w 27 6',
#   'w 27 7',
#   'w 27 8',
#   'w 27 9',
#   'w 27 14',
#   'w 27 15',
#   'w 27 16',
#   'w 28 3',
#   'w 28 4',
#   'w 28 5',
#   'w 28 6',
#   'w 28 7',
#   'w 28 8',
#   'w 28 9',
#   'w 28 10',
#   'w 28 11',
#   'w 28 12',
#   'w 28 14',
#   'w 28 15',
#   'w 28 16',
#   'w 28 18',
#   'w 29 1',
#   'w 29 2',
#   'w 29 3',
#   'w 29 4',
#   'w 29 5',
#   'w 29 6',
#   'w 29 7',
#   'w 29 8',
#   'w 29 9',
#   'w 29 10',
#   'w 29 11',
#   'w 29 12',
#   'w 29 14',
#   'w 29 15',
#   'w 29 16',
#   'w 29 18',
#   'w 30 3',
#   'w 30 4',
#   'w 30 5',
#   'w 30 6',
#   'w 30 7',
#   'w 30 8',
#   'w 30 9',
#   'w 30 10',
#   'w 30 11',
#   'w 30 15',
#   'w 31 1',
#   'w 31 3',
#   'w 31 4',
#   'w 31 5',
#   'w 31 6',
#   'w 31 7',
#   'w 31 8',
#   'w 31 9',
#   'w 31 10',
#   'w 31 11',
#   'w 31 13',
#   'w 31 17',
#   'w 31 18',
#   'w 32 1',
#   'w 32 5',
#   'w 32 6',
#   'w 32 7',
#   'w 32 8',
#   'w 32 13',
#   'w 32 15',
#   'w 32 17',
#   'w 32 18',
#   'w 33 1',
#   'w 33 2',
#   'w 33 3',
#   'w 33 10',
#   'w 33 11',
#   'w 33 12',
#   'w 33 13',
#   'w 33 15',
#   'w 33 17',
#   'w 33 18',
#   'w 34 5',
#   'w 34 6',
#   'w 34 7',
#   'w 34 8',
#   'p 0 0',
#   'p 21 13',
#   'p 17 0',
#   'p 34 16',
#   'p 1 8',
#   'p 19 6',
#   'p 24 19',
#   'p 30 19',
#   'p 6 13',
#   'p 15 6',
#   'p 27 19',
#   'p 9 17',
#   'p 3 15',
#   'p 13 11',
#   'p 33 4',
#   't 1400 0',
#   'm 0 18',
#   '0 33 0',
#   '1 33 0',
#   '2 34 1',
#   't 1399 0',
#   'm 0 17',
#   '0 32 0',
#   '1 34 0',
#   '2 34 0',
#   't 1398 0',
#   'm 0 16',
#   '0 33 0',
#   '1 33 0',
#   '2 34 1',
#   'f 16 0',
#   't 1397 0',
#   'm 1 16',
#   '0 34 0',
#   '1 34 0',
#   '2 34 0',
#   't 1396 0',
#   'm 2 16',
#   '0 33 0',
#   '1 33 0',
#   '2 34 1',
#   't 1395 0',
#   'm 3 16',
#   '0 32 0',
#   '1 34 0',
#   '2 34 2',
#   't 1394 0',
#   'm 2 16',
#   '0 33 0',
#   '1 33 0',
#   '2 34 1',
#   't 1393 0',
#   'm 2 16',
#   '0 32 0',
#   '1 32 0',
#   '2 34 2',
#   't 1392 0',
#   'm 2 16',
#   '0 33 0',
#   '1 33 0',
#   '2 34 1',
#   't 1391 0',
#   'm 2 16',
#   '0 32 0',
#   '1 34 0',
#   '2 34 2',
#   't 1390 0',
#   'm 3 16',
#   '0 33 0',
#   '1 34 1',
#   '2 34 3',
#   't 1389 0',
#   'm 4 16',
#   '0 34 0',
#   '1 34 0',
#   '2 34 2',
#   't 1388 0',
#   'm 4 17',
#   '0 34 1',
#   '1 33 0',
#   '2 34 3',
#   't 1387 0',
#   'm 4 18',
#   '0 34 2',
#   '1 34 0',
#   '2 34 2',
#   't 1386 0',
#   'm 4 19',
#   '0 34 1',
#   '1 33 0',
#   '2 34 3',
#   't 1385 0',
#   'm 5 19',
#   '0 34 2',
#   '1 34 0',
#   '2 34 4',
#   't 1384 0',
#   'm 4 19',
#   '0 34 1',
#   '1 34 1',
#   '2 33 4',
#   't 1383 0',
#   'm 3 19',
#   '0 34 0',
#   '1 34 0',
#   '2 33 5',
#   't 1382 0',
#   'm 4 19',
#   '0 34 1',
#   '1 33 0',
#   '2 33 6',
#   't 1381 0',
#   'm 4 18',
#   '0 34 2',
#   '1 32 0',
#   '2 33 7',
#   't 1380 0',
#   'm 4 17',
#   '0 34 1',
#   '1 31 0',
#   '2 33 8',
#   't 1379 0',
#   'm 4 16',
#   '0 34 2',
#   '1 32 0',
#   '2 33 9',
#   't 1378 0',
#   'm 4 17',
#   '0 34 3',
#   '1 31 0',
#   '2 32 9',
#   't 1377 0',
#   'm 5 17',
#   '0 34 4',
#   '1 32 0',
#   '2 32 10',
#   't 1376 0',
#   'm 6 17',
#   '0 34 3',
#   '1 33 0',
#   '2 32 11',
#   't 1375 0',
#   'm 5 17',
#   '0 34 2',
#   '1 34 0',
#   '2 32 10',
#   't 1374 0',
#   'm 4 17',
#   '0 34 1',
#   '1 34 1',
#   '2 32 11',
#   't 1373 0',
#   'm 4 16',
#   '0 34 0',
#   '1 34 0',
#   '2 32 12',
#   't 1372 0',
#   'm 3 16',
#   '0 33 0',
#   '1 33 0',
#   '2 31 12',
#   't 1371 0',
#   'm 2 16',
#   '0 34 0',
#   '1 32 0',
#   '2 32 12',
#   't 1370 0',
#   'm 1 16',
#   '0 34 1',
#   '1 31 0',
#   '2 31 12',
#   't 1369 0',
#   'm 2 16',
#   '0 34 2',
#   '1 32 0',
#   '2 30 12',
#   't 1368 0',
#   'm 3 16',
#   '0 34 1',
#   '1 33 0',
#   '2 30 13',
#   't 1367 0',
#   'm 3 15',
#   '0 34 2',
#   '1 34 0',
#   '2 30 12',
#   't 1366 6',
#   'm 3 15',
#   '0 34 1',
#   '1 33 0',
#   '2 30 13',
#   't 1365 6',
#   'm 3 14',
#   '0 34 0',
#   '1 32 0',
#   '2 30 12',
#   't 1364 6',
#   'm 4 14',
#   '0 34 1',
#   '1 31 0',
#   '2 30 13',
#   't 1363 6',
#   'm 3 14',
#   '0 34 0',
#   '1 32 0',
#   '2 30 12',
#   't 1362 6',
#   'm 4 14',
#   '0 34 1',
#   '1 33 0',
#   '2 30 13',
#   't 1361 6',
#   'm 4 14',
#   '0 34 0',
#   '1 32 0',
#   '2 29 13',
#   't 1360 6',
#   'm 4 13',
#   '0 34 1',
#   '1 33 0',
#   '2 28 13',
#   't 1359 6',
#   'm 4 13',
#   '0 34 2',
#   '1 32 0',
#   '2 27 13',
#   't 1358 6',
#   'm 5 13',
#   '0 34 1',
#   '1 31 0',
#   '2 27 12',
#   't 1357 6',
#   'm 6 13',
#   '0 34 0',
#   '1 30 0',
#   '2 27 11',
#   't 1356 13',
#   'm 5 13',
#   '0 33 0',
#   '1 29 0',
#   '2 27 12',
#   't 1355 13',
#   'm 4 13',
#   '0 34 0',
#   '1 30 0',
#   '2 27 13',
#   't 1354 13',
#   'm 4 14',
#   '0 33 0',
#   '1 29 0',
#   '2 27 12',
#   't 1353 13',
#   'm 4 13',
#   '0 34 0',
#   '1 30 0',
#   '2 27 11',
#   't 1352 13',
#   'm 5 13',
#   '0 33 0',
#   '1 30 1',
#   '2 27 10',
#   't 1351 13',
#   'm 6 13',
#   '0 34 0',
#   '1 30 2',
#   '2 27 11',
#   't 1350 13',
#   'm 7 13',
#   '0 34 1',
#   '1 30 1',
#   '2 27 12',
#   't 1349 13',
#   'm 6 13',
#   '0 34 0',
#   '1 30 0',
#   '2 27 11',
#   't 1348 13',
#   'm 7 13',
#   '0 33 0',
#   '1 29 0',
#   '2 27 12',
#   't 1347 13',
#   'm 7 13',
#   '0 32 0',
#   '1 30 0',
#   '2 27 11',
#   't 1346 13',
#   'm 7 13',
#   '0 33 0',
#   '1 31 0',
#   '2 27 10',
#   't 1345 13',
#   'm 7 13',
#   '0 34 0',
#   '1 32 0',
#   '2 26 10',
#   't 1344 13',
#   'm 7 13',
#   '0 34 1',
#   '1 33 0',
#   '2 27 10',
#   't 1343 13',
#   'm 7 13',
#   '0 34 2',
#   '1 34 0',
#   '2 27 11',
#   't 1342 13',
#   'm 6 13',
#   '0 34 1',
#   '1 33 0',
#   '2 27 10',
#   't 1341 13',
#   'm 6 13',
#   '0 34 0',
#   '1 34 0',
#   '2 27 11',
#   't 1340 13',
#   'm 6 13',
#   '0 33 0',
#   '1 33 0',
#   '2 27 12',
#   't 1339 13',
#   'm 6 13',
#   '0 34 0',
#   '1 34 0',
#   '2 27 11',
#   't 1338 13',
#   'm 6 13',
#   '0 34 1',
#   '1 34 1',
#   '2 27 12',
#   't 1337 13',
#   'm 5 13',
#   '0 34 0',
#   '1 34 2',
#   '2 27 11',
#   't 1336 13',
#   'm 5 13',
#   '0 33 0',
#   '1 34 1',
#   '2 27 12',
#   't 1335 13',
#   'm 5 13',
#   '0 32 0',
#   '1 34 2',
#   '2 27 11',
#   't 1334 13',
#   'm 5 13',
#   '0 33 0',
#   '1 34 1',
#   '2 27 10',
#   't 1333 13',
#   'm 6 13',
#   '0 32 0',
#   '1 34 0',
#   '2 27 11',
#   't 1332 13',
#   'm 6 13',
#   '0 33 0',
#   '1 34 1',
#   '2 27 12',
#   't 1331 13',
#   'm 7 13',
#   '0 34 0',
#   '1 34 0',
#   '2 27 13',
#   't 1330 13',
#   'm 7 13',
#   '0 34 1',
#   '1 34 1',
#   '2 28 13',
#   't 1329 13',
#   'm 6 13',
#   '0 34 2',
#   '1 34 2',
#   '2 27 13',
#   't 1328 13',
#   'm 6 13',
#   '0 34 3',
#   '1 34 3',
#   '2 28 13',
#   't 1327 13',
#   'm 6 13',
#   '0 34 2',
#   '1 34 4',
#   '2 27 13',
#   't 1326 13',
#   'm 7 13',
#   '0 34 3',
#   '1 33 4',
#   '2 28 13',
#   't 1325 13',
#   'm 6 13',
#   '0 34 4',
#   '1 34 4',
#   '2 27 13',
#   't 1324 13',
#   'm 5 13',
#   '0 34 3',
#   '1 33 4',
#   '2 28 13',
#   't 1323 13',
#   'm 6 13',
#   '0 34 4',
#   '1 33 5',
#   '2 29 13',
#   't 1322 13',
#   'm 7 13',
#   '0 34 3',
#   '1 33 6',
#   '2 28 13',
#   't 1321 13',
#   'm 6 13',
#   '0 34 4',
#   '1 33 5',
#   '2 27 13',
#   't 1320 13',
#   'm 5 13',
#   '0 33 4',
#   '1 33 6',
#   '2 27 12',
#   't 1319 13',
#   'm 4 13',
#   '0 33 5',
#   '1 33 7',
#   '2 27 13',
#   't 1318 13',
#   'm 4 12',
#   '0 33 4',
#   '1 33 8',
#   '2 27 12',
#   't 1317 13',
#   'm 3 12',
#   '0 32 4',
#   '1 33 7',
#   '2 27 11',
#   't 1316 13',
#   'm 4 12',
#   '0 32 3',
#   '1 33 6',
#   '2 27 10',
#   't 1315 13',
#   'm 4 12',
#   '0 32 2',
#   '1 33 5',
#   '2 27 11',
#   't 1314 13',
#   'm 4 13',
#   '0 31 2',
#   '1 33 6',
#   '2 27 12',
#   't 1313 13',
#   'm 4 12',
#   '0 30 2',
#   '1 33 7',
#   '2 27 13',
#   't 1312 13',
#   'm 4 12',
#   '0 31 2',
#   '1 33 6',
#   '2 27 12',
#   't 1311 13',
#   'm 3 12',
#   '0 32 2',
#   '1 33 7',
#   '2 27 13',
#   't 1310 13',
#   'm 3 12',
#   '0 32 3',
#   '1 33 6',
#   '2 27 12',
#   't 1309 13',
#   'm 3 12',
#   '0 32 2',
#   '1 33 5',
#   '2 27 11',
#   't 1308 13',
#   'm 3 12',
#   '0 31 2',
#   '1 33 4',
#   '2 27 12',
#   't 1307 13',
#   'm 2 12',
#   '0 32 2',
#   '1 34 4',
#   '2 27 13',
#   't 1306 13',
#   'm 2 11',
#   '0 32 3',
#   '1 33 4',
#   '2 27 12',
#   't 1305 13',
#   'm 2 10',
#   '0 32 2',
#   '1 32 4',
#   '2 27 13',
#   't 1304 13',
#   'm 2 9',
#   '0 32 3',
#   '1 33 4',
#   '2 27 12',
#   't 1303 13',
#   'm 1 9',
#   '0 32 4',
#   '1 34 4',
#   '2 27 13',
#   't 1302 13',
#   'm 1 9',
#   '0 33 4',
#   '1 34 3',
#   '2 28 13',
#   't 1301 13',
#   'm 1 9',
#   '0 33 5',
#   '1 34 2',
#   '2 29 13',
#   't 1300 13',
#   'm 1 9',
#   '0 33 6',
#   '1 34 1',
#   '2 30 13',
#   't 1299 13',
#   'm 1 8',
#   '0 33 7',
#   '1 34 0',
#   '2 30 14',
#   't 1298 20',
#   'm 1 7',
#   '0 33 6',
#   '1 34 1',
#   '2 30 13',
#   't 1297 20',
#   'm 1 8',
#   '0 33 7',
#   '1 34 2',
#   '2 30 12',
#   't 1296 20',
#   'm 1 8',
#   '0 33 6',
#   '1 34 1',
#   '2 30 13',
#   't 1295 20',
#   'm 1 9',
#   '0 33 5',
#   '1 34 0',
#   '2 30 12',
#   't 1294 20',
#   'm 0 9',
#   '0 33 4',
#   '1 33 0',
#   '2 30 13',
#   't 1293 20',
#   'm 0 9',
#   '0 34 4',
#   '1 34 0',
#   '2 30 14',
#   't 1292 20',
#   'm 0 10',
#   '0 34 3',
#   '1 34 1',
#   '2 31 14',
#   't 1291 20',
#   'm 0 11',
#   '0 34 2',
#   '1 34 0',
#   '2 30 14',
#   't 1290 20',
#   'm 0 10',
#   '0 34 3',
#   '1 34 1',
#   '2 30 13',
#   't 1289 20',
#   'm 0 11',
#   '0 34 2',
#   '1 34 2',
#   '2 29 13',
#   't 1288 20',
#   'm 0 11',
#   '0 34 3',
#   '1 34 1',
#   ...],
#  <tree_genotype.TreeGenotype at 0x7f89b0a66e20>,
#  -13.303887755102041,
#  10.275)

# %% [markdown]
# ## Tuning
# As is the case with all evolutionary algorithms, tuning your genetic programming algorithm is very important! In this case, it's also a graded component of the Algorithmic section of this assignment. As was the case with Assignment 1b, hand-tuning the algorithm parameters using a couple runs at a time is good enough for this class. Like Assignment 1b, you are expected to tune your algorithm parameters to a degree that your full GP outperforms the ramped half-and-half algorithm used in Assignment 2a (note that the default parameters are intentionally bad). While tuning, it can be helpful to ask yourself the following:
#  * How many generations of evolution will occur based on $\mu$ and $\lambda$?
#  * Is premature convergence occuring (e.g., max fitness is mediocre and does not increase)?
#  * Is a loss of diversity preventing improvement (e.g., mean and best fitness approach convergence prematurely)?
#  * If tuning $k$, is $k$-tournament actually being used as a selection method?
#  * Have the problem instance or search space parameters been manipulated in a way that invalidates a comparison with ramped half-and-half (i.e., avoid manipulating the game parameters and tree depth limits)?
#  * Is the parsimony coefficient tuned well? (Note: you'll need to consider this explicitly if attempting the YELLOW deliverable)
#
# Use the following cell to tune the parameters in './configs/green2b_config.txt'.

# %%
# feel free to change these values and re-run this cell as much as you'd like
number_runs = 5
number_evaluations = 2000
config_filename = './configs/green2b_config.txt'

runsData = list()

# tuning runs can be called here

for runCount in range(number_runs):
    print(f'Run # {runCount}')
    runsData.append(genetic_programming_search(2000, './configs/green2b_config.txt', runCount))
    
runsDataBestFitnesses = [runData[0] for runData in runsData]
overallBestFitness = max(runsDataBestFitnesses)
          
runsDataBestLogs = [runData[1] for runData in runsData]
overallBestLog = runsDataBestLogs[runsDataBestFitnesses.index(overallBestFitness)]
          
runsDataBestTrees = [runData[2] for runData in runsData]
overallBestTree = runsDataBestTrees[runsDataBestFitnesses.index(overallBestFitness)]

runsDataAveFitnesses = [runData[3] for runData in runsData]
runsDataAveBestFitnesses = [runData[4] for runData in runsData]


print(f'Best Fitness {overallBestFitness}')

game_log_path = 'worldFiles/tuningBest.txt'
with open(game_log_path, 'w') as f:
    [f.write(f'{line}\n') for line in overallBestLog]
          
print('Best Tree')
print(overallBestTree.print())

plt.figure()
plt.title(f'Mult-run experiement best and average fitnesses')
plt.xlabel('Runs')
plt.ylabel('Fitness')
plt.plot(range(number_runs), runsDataAveBestFitnesses, label="Average Best Fitness")
plt.plot(range(number_runs), runsDataAveFitnesses, label="Average Fitness")
plt.legend(loc="upper right")
# Out:
# Run # 0
# Run # 1
# Run # 2
# Run # 3
# Run # 4
# Best Fitness 85
# Best Tree
# -
# |+
# ||-
# |||G
# |||P
# ||-
# |||P
# |||P
# |*
# ||RAND
# |||P
# |||M
# ||-
# |||F
# |||W

# %% [markdown]
# ## Multi-Run Experiments
# Implement a full 30-run experiment with 2,000 fitness evaluations per run. For each generation, log the average fitness and best fitness of the current population. Average this data across all 30 runs to produce a plot of fitness vs evaluations with average and best fitness averaged across all 30 runs. For each run, log the best (unpenalized/raw) fitness encountered for statistical analysis with your results from Assignment 2a. For the individual with the highest fitness of the full 30-run experiment, save the log for visualization and informal analysis and comparison with the best agent from Assignment 2a.

# %%
number_runs = 30
number_evaluations = 2000
config_filename = './configs/green2b_config.txt'

# Implement your 30-run experiment here

runsData = list()

# tuning runs can be called here

for runCount in range(number_runs):
    print(f'Run # {runCount}')
    runsData.append(genetic_programming_search(number_evaluations, config_filename, runCount))
    
runsDataBestFitnesses = [runData[0] for runData in runsData]
overallBestFitness = max(runsDataBestFitnesses)

runsDataBestRawFitnesses = [runData[2].raw_fitness for runData in runsData]
          
runsDataBestLogs = [runData[1] for runData in runsData]
overallBestLog = runsDataBestLogs[runsDataBestFitnesses.index(overallBestFitness)]
          
runsDataBestTrees = [runData[2] for runData in runsData]
overallBestTree = runsDataBestTrees[runsDataBestFitnesses.index(overallBestFitness)]

runsDataAveFitnesses = [runData[3] for runData in runsData]
runsDataAveBestFitnesses = [runData[4] for runData in runsData]

print(f'Overall Best Fitness(penalized): {overallBestFitness}')

game_log_path = 'worldFiles/overallGreenBest.txt'
with open(game_log_path, 'w') as f:
    [f.write(f'{line}\n') for line in overallBestLog]
          
#print('Best Tree')
#print(overallBestTree.print())
with open(f'solutions/bestGreenRunTree.txt','w') as f:
    f.write(overallBestTree.print())

with open('./data/green/bestRawFitnesses.txt', 'w') as fp:
    for fitness in runsDataBestRawFitnesses:
        fp.write(f'{fitness}\n')

plt.figure()
plt.title(f'Mult-run experiement best and average fitnesses')
plt.xlabel('Runs')
plt.ylabel('Fitness')
plt.plot(range(number_runs), runsDataAveBestFitnesses, label="Average Best Fitness")
plt.plot(range(number_runs), runsDataAveFitnesses, label="Average Fitness")
plt.legend(loc="upper right")
# Out:
# Run # 0
# Run # 1
# Run # 2
# Run # 3
# Run # 4
# Run # 5
# Run # 6
# Run # 7
# Run # 8
# Run # 9
# Run # 10
# Run # 11
# Run # 12
# Run # 13
# Run # 14
# Run # 15
# Run # 16
# Run # 17
# Run # 18
# Run # 19
# Run # 20
# Run # 21
# Run # 22
# Run # 23
# Run # 24
# Run # 25
# Run # 26
# Run # 27
# Run # 28
# Run # 29
# Overall Best Fitness(penalized): 121

# %% [markdown]
# ## Report
# See Assignment Description Document for report details.
#
# # YELLOW Deliverable
# Now that you've completed the GREEN deliverable and conducted an experiment with one of the parsimony metrics (e.g., tree depth or tree size), experiment with the other metric and tune the parsimony coefficient. You are welcome to re-use the other parameters you used in your GREEN configuration, but some attempt at tuning the parsimony coefficient to account for the new parsimony metric is required.
#
# ***Note***: You should add a corresponding parameter to your config files that enables the selection of a parsimony metric.
#
# Use the following 2 cells to tune and conduct a 30-run experiment, respectively:

# %%
number_runs = 30
number_evaluations = 2000
config_filename = './configs/yellow2b_config.txt'

runsData = list()

# tuning runs can be called here

for runCount in range(number_runs):
    print(f'Run # {runCount}')
    runsData.append(genetic_programming_search(number_evaluations, config_filename, runCount))
    
runsDataBestFitnesses = [runData[0] for runData in runsData]
overallBestFitness = max(runsDataBestFitnesses)

runsDataBestRawFitnesses = [runData[2].raw_fitness for runData in runsData]
          
runsDataBestLogs = [runData[1] for runData in runsData]
overallBestLog = runsDataBestLogs[runsDataBestFitnesses.index(overallBestFitness)]
          
runsDataBestTrees = [runData[2] for runData in runsData]
overallBestTree = runsDataBestTrees[runsDataBestFitnesses.index(overallBestFitness)]

runsDataAveFitnesses = [runData[3] for runData in runsData]
runsDataAveBestFitnesses = [runData[4] for runData in runsData]

print(f'Overall Best Fitness(penalized): {overallBestFitness}')

game_log_path = 'worldFiles/overallBestYellowDepthParsimony.txt'
with open(game_log_path, 'w') as f:
    [f.write(f'{line}\n') for line in overallBestLog]
          
print('Best Tree')
#print(overallBestTree.print())
with open(f'solutions/bestYellowDepthParsimonyRunTree.txt','w') as f:
    f.write(overallBestTree.print())

with open('./data/yellow/depth_parsimony/bestRawFitnesses.txt', 'w') as fp:
    for fitness in runsDataBestRawFitnesses:
        fp.write(f'{fitness}\n')

plt.figure()
plt.title(f'Mult-run experiement best and average fitnesses (Depth Parsimony)')
plt.xlabel('Runs')
plt.ylabel('Fitness')
plt.plot(range(number_runs), runsDataAveBestFitnesses, label="Average Best Fitness")
plt.plot(range(number_runs), runsDataAveFitnesses, label="Average Fitness")
plt.legend(loc="upper right")
# Out:
# Run # 0
# Run # 1
# Run # 2
# Run # 3
# Run # 4
# Run # 5
# Run # 6
# Run # 7
# Run # 8
# Run # 9
# Run # 10
# Run # 11
# Run # 12
# Run # 13
# Run # 14
# Run # 15
# Run # 16
# Run # 17
# Run # 18
# Run # 19
# Run # 20
# Run # 21
# Run # 22
# Run # 23
# Run # 24
# Run # 25
# Run # 26
# Run # 27
# Run # 28
# Run # 29
# Overall Best Fitness(penalized): 176
# Best Tree

# %% [markdown]
# # RED Deliverables (Bonus)
# For each RED deliverable you attempt, create new notebook cells as necessary and do not overwrite or break compatibility with your previous experimentation. Bonus RED deliverables are typically somewhat open-ended, but this is particularly true in Assignment Series 2. As such, you may encounter unanticipated design decisions and obstacles that you should figure out how to overcome. TA assistance is available to answer questions, though you are expected to experiment and investigate solutions/answers prior to seeking this assistance. You are welcome to re-use tuned parameters between these experiments instead of more rigorous tuning, though you may observe more interesting results with per-deliverable tuning. Finally, the components implemented for the Assignment 2b RED deliverables may reappear in RED deliverables of Assignment 2c. The RED deliverables for Assignment 2c are undecided, but recall that Assignment 2c is worth double points and percentage-based bonuses are consequently quite valuable to the overall Assignment Series 2 grade.
#
# ***Note***: When attempting deliverables RED 3 and 4, feel free to use the provided random Pac-Man controller as the static agent.
#
# Create cells below to perform your RED deliverable experiments.

# %% [markdown]
# ## Red 1 Multiple Identical Pac-Man Controllers
#
# For this section I added the 'M' token to the sensor nodes to represent the distance between one player and the other players. I also added this to the tree_check.py file so that my trees would pass check when running through the whole notebook.

# %% [markdown]
# #### Red 1 full run cell

# %%
number_runs = 30
number_evaluations = 2000
config_filename = './configs/red1_2b_config.txt'

runsData = list()

for runCount in range(number_runs):
    print(f'Run # {runCount}')
    runsData.append(genetic_programming_search(number_evaluations, config_filename, runCount))
    
runsDataBestFitnesses = [runData[0] for runData in runsData]
overallBestFitness = max(runsDataBestFitnesses)

runsDataBestRawFitnesses = [runData[2].raw_fitness for runData in runsData]
          
runsDataBestLogs = [runData[1] for runData in runsData]
overallBestLog = runsDataBestLogs[runsDataBestFitnesses.index(overallBestFitness)]
          
runsDataBestTrees = [runData[2] for runData in runsData]
overallBestTree = runsDataBestTrees[runsDataBestFitnesses.index(overallBestFitness)]

runsDataAveFitnesses = [runData[3] for runData in runsData]
runsDataAveBestFitnesses = [runData[4] for runData in runsData]

print(f'Overall Best Fitness(penalized): {overallBestFitness}')

game_log_path = 'worldFiles/overallBestRed1.txt'
with open(game_log_path, 'w') as f:
    [f.write(f'{line}\n') for line in overallBestLog]
          
print('Best Tree')
#print(overallBestTree.print())
with open(f'solutions/bestRed1Tree.txt','w') as f:
    f.write(overallBestTree.print())

with open('./data/redOne/bestRawFitnesses.txt', 'w') as fp:
    for fitness in runsDataBestRawFitnesses:
        fp.write(f'{fitness}\n')

plt.figure()
plt.title(f'Mult-run experiement best and average fitnesses (Multiple Identical Pac-Man Controllers)')
plt.xlabel('Runs')
plt.ylabel('Fitness')
plt.plot(range(number_runs), runsDataAveBestFitnesses, label="Average Best Fitness")
plt.plot(range(number_runs), runsDataAveFitnesses, label="Average Fitness")
plt.legend(loc="upper right")
# Out:
# Run # 0
# Run # 1
# Run # 2
# Run # 3
# Run # 4
# Run # 5
# Run # 6
# Run # 7
# Run # 8
# Run # 9
# Run # 10
# Run # 11
# Run # 12
# Run # 13
# Run # 14
# Run # 15
# Run # 16
# Run # 17
# Run # 18
# Run # 19
# Run # 20
# Run # 21
# Run # 22
# Run # 23
# Run # 24
# Run # 25
# Run # 26
# Run # 27
# Run # 28
# Run # 29
# Overall Best Fitness(penalized): 111
# Best Tree

# %% [markdown]
# ### Red 3 Multiple Identical Ghost Controllers
#
# Files created for this experiment:
#
# - ghost_parse_tree.py
# - ghost_tree_genotype.py
#
# I also created a copy of basic_population_evaluation, called ghost_basic_population_evaluation that calculated the individual's raw fitness using the negative game score plus remaining game time specified in the directions. Number of nodes in tree was used as the parimony pressure metric.

# %%
from gpac_population_evaluation import ghost_basic_population_evaluation
from ghost_tree_genotype import *
from ghost_parse_tree import *


# implement your GP here
def ghost_genetic_programming_search(number_evaluations, config_filename, run_number):
    best_fitness = -inf
    best_log = None
    best_tree = None
    data = []
    
    # Parse the config and implement your EA here.
    # Feel free to focus on implementation first and then return for data collection.
    
    config = read_config(config_filename, globalVars=globals(), localVars=locals())

    # full initialization of your GP population
    example_EA = GeneticProgrammingPopulation(**config['EA_configs'], **config)
    ghost_basic_population_evaluation(example_EA.population, **config['fitness_kwargs'])
    example_EA.evaluations = len(example_EA.population)
    fitnesses = [individual.fitness for individual in example_EA.population]
    
    data.append([statistics.mean(fitnesses), max(fitnesses)])

    with open('./data/redThree/run' + str(run_number) + 'Data.txt', 'w') as fp:
        fp.write(f'Number of Evaluations: {example_EA.evaluations}\n')
        fp.write(f'Best Fitness: {max(fitnesses)}\n')
        fp.write(f'Average Fitness: {statistics.mean(fitnesses)}\n')
        fp.write('------------------------\n')
    
    #print(f'Average fitness of population: {statistics.mean(fitnesses)}')
    #print(f'Best fitness in population: {max(fitnesses)}')
    #print(f'Number of fitness evaluations: {example_EA.evaluations}')
    
    while not(example_EA.evaluations >= number_evaluations):
        
        # generate children
        children = example_EA.generate_children()
        ghost_basic_population_evaluation(children, **config['fitness_kwargs'])
        example_EA.evaluations += len(children)
        children_fitnesses = [individual.fitness for individual in children]
        
        if(max(children_fitnesses) > best_fitness):
            best_fitness = max(children_fitnesses)
            best_log = children[children_fitnesses.index(best_fitness)].log
            best_tree = children[children_fitnesses.index(best_fitness)]
            #print(f'\tNew best fitness: {best_fitness}')
            #print(f'\tRaw Fitness: {best_tree.raw_fitness}')
        
        data.append([statistics.mean(children_fitnesses), max(children_fitnesses)])
        
        with open('./data/redThree/run' + str(run_number) + 'Data.txt', 'a') as fp:
            fp.write(f'Number of Evaluations: {example_EA.evaluations}\n')
            fp.write(f'Best Fitness: {max(children_fitnesses)}\n')
            fp.write(f'Average Fitness: {statistics.mean(children_fitnesses)}\n')
            fp.write('------------------------\n')
        
        
        #print(f'Average fitness of population: {statistics.mean(children_fitnesses)}')
        #print(f'Best fitness in population: {max(children_fitnesses)}')
        #print(f'Number of fitness evaluations: {example_EA.evaluations}')
        #print('-------------------')
            
    #game_log_path = 'worldFiles/testSingleRun.txt'
    #with open(game_log_path, 'w') as f:
    #    [f.write(f'{line}\n') for line in best_log]
        
    #print('Best Tree')
    #print(best_tree.print())
    
    overallAverageFitness = statistics.mean([gen[0] for gen in data])
    overallAverageBestFitness = statistics.mean([gen[1] for gen in data])
    
    return best_fitness, best_log, best_tree, overallAverageFitness, overallAverageBestFitness

# %%
# testing 
ghost_genetic_programming_search(2000, './configs/red3_2b_config.txt', 0)
# Out:
# Average fitness of population: 215.28
# Best fitness in population: 1159
# Number of fitness evaluations: 50
# 	New best fitness: 1260
# 	Raw Fitness: 1268
# Number of fitness evaluations: 57
# -------------------
# Number of fitness evaluations: 64
# -------------------
# Number of fitness evaluations: 71
# -------------------
# Number of fitness evaluations: 78
# -------------------
# 	New best fitness: 1277
# 	Raw Fitness: 1285
# Number of fitness evaluations: 85
# -------------------
# Number of fitness evaluations: 92
# -------------------
# Number of fitness evaluations: 99
# -------------------
# Number of fitness evaluations: 106
# -------------------
# Number of fitness evaluations: 113
# -------------------
# Number of fitness evaluations: 120
# -------------------
# 	New best fitness: 1293
# 	Raw Fitness: 1301
# Number of fitness evaluations: 127
# -------------------
# Number of fitness evaluations: 134
# -------------------
# Number of fitness evaluations: 141
# -------------------
# Number of fitness evaluations: 148
# -------------------
# Number of fitness evaluations: 155
# -------------------
# Number of fitness evaluations: 162
# -------------------
# Number of fitness evaluations: 169
# -------------------
# Number of fitness evaluations: 176
# -------------------
# Number of fitness evaluations: 183
# -------------------
# Number of fitness evaluations: 190
# -------------------
# Number of fitness evaluations: 197
# -------------------
# Number of fitness evaluations: 204
# -------------------
# Number of fitness evaluations: 211
# -------------------
# Number of fitness evaluations: 218
# -------------------
# Number of fitness evaluations: 225
# -------------------
# Number of fitness evaluations: 232
# -------------------
# Number of fitness evaluations: 239
# -------------------
# Number of fitness evaluations: 246
# -------------------
# Number of fitness evaluations: 253
# -------------------
# Number of fitness evaluations: 260
# -------------------
# Number of fitness evaluations: 267
# -------------------
# Number of fitness evaluations: 274
# -------------------
# Number of fitness evaluations: 281
# -------------------
# 	New best fitness: 1313
# 	Raw Fitness: 1321
# Number of fitness evaluations: 288
# -------------------
# Number of fitness evaluations: 295
# -------------------
# Number of fitness evaluations: 302
# -------------------
# Number of fitness evaluations: 309
# -------------------
# Number of fitness evaluations: 316
# -------------------
# Number of fitness evaluations: 323
# -------------------
# Number of fitness evaluations: 330
# -------------------
# Number of fitness evaluations: 337
# -------------------
# Number of fitness evaluations: 344
# -------------------
# Number of fitness evaluations: 351
# -------------------
# Number of fitness evaluations: 358
# -------------------
# Number of fitness evaluations: 365
# -------------------
# 	New best fitness: 1318
# 	Raw Fitness: 1328
# Number of fitness evaluations: 372
# -------------------
# Number of fitness evaluations: 379
# -------------------
# Number of fitness evaluations: 386
# -------------------
# Number of fitness evaluations: 393
# -------------------
# Number of fitness evaluations: 400
# -------------------
# Number of fitness evaluations: 407
# -------------------
# Number of fitness evaluations: 414
# -------------------
# Number of fitness evaluations: 421
# -------------------
# Number of fitness evaluations: 428
# -------------------
# Number of fitness evaluations: 435
# -------------------
# Number of fitness evaluations: 442
# -------------------
# Number of fitness evaluations: 449
# -------------------
# Number of fitness evaluations: 456
# -------------------
# Number of fitness evaluations: 463
# -------------------
# Number of fitness evaluations: 470
# -------------------
# Number of fitness evaluations: 477
# -------------------
# Number of fitness evaluations: 484
# -------------------
# Number of fitness evaluations: 491
# -------------------
# Number of fitness evaluations: 498
# -------------------
# Number of fitness evaluations: 505
# -------------------
# Number of fitness evaluations: 512
# -------------------
# Number of fitness evaluations: 519
# -------------------
# Number of fitness evaluations: 526
# -------------------
# Number of fitness evaluations: 533
# -------------------
# Number of fitness evaluations: 540
# -------------------
# Number of fitness evaluations: 547
# -------------------
# Number of fitness evaluations: 554
# -------------------
# Number of fitness evaluations: 561
# -------------------
# Number of fitness evaluations: 568
# -------------------
# Number of fitness evaluations: 575
# -------------------
# Number of fitness evaluations: 582
# -------------------
# Number of fitness evaluations: 589
# -------------------
# Number of fitness evaluations: 596
# -------------------
# Number of fitness evaluations: 603
# -------------------
# Number of fitness evaluations: 610
# -------------------
# Number of fitness evaluations: 617
# -------------------
# Number of fitness evaluations: 624
# -------------------
# Number of fitness evaluations: 631
# -------------------
# Number of fitness evaluations: 638
# -------------------
# Number of fitness evaluations: 645
# -------------------
# Number of fitness evaluations: 652
# -------------------
# Number of fitness evaluations: 659
# -------------------
# Number of fitness evaluations: 666
# -------------------
# Number of fitness evaluations: 673
# -------------------
# Number of fitness evaluations: 680
# -------------------
# Number of fitness evaluations: 687
# -------------------
# Number of fitness evaluations: 694
# -------------------
# Number of fitness evaluations: 701
# -------------------
# Number of fitness evaluations: 708
# -------------------
# Number of fitness evaluations: 715
# -------------------
# Number of fitness evaluations: 722
# -------------------
# Number of fitness evaluations: 729
# -------------------
# Number of fitness evaluations: 736
# -------------------
# Number of fitness evaluations: 743
# -------------------
# Number of fitness evaluations: 750
# -------------------
# Number of fitness evaluations: 757
# -------------------
# Number of fitness evaluations: 764
# -------------------
# Number of fitness evaluations: 771
# -------------------
# Number of fitness evaluations: 778
# -------------------
# Number of fitness evaluations: 785
# -------------------
# Number of fitness evaluations: 792
# -------------------
# Number of fitness evaluations: 799
# -------------------
# Number of fitness evaluations: 806
# -------------------
# Number of fitness evaluations: 813
# -------------------
# Number of fitness evaluations: 820
# -------------------
# Number of fitness evaluations: 827
# -------------------
# 	New best fitness: 1333
# 	Raw Fitness: 1337
# Number of fitness evaluations: 834
# -------------------
# Number of fitness evaluations: 841
# -------------------
# Number of fitness evaluations: 848
# -------------------
# Number of fitness evaluations: 855
# -------------------
# Number of fitness evaluations: 862
# -------------------
# Number of fitness evaluations: 869
# -------------------
# Number of fitness evaluations: 876
# -------------------
# Number of fitness evaluations: 883
# -------------------
# Number of fitness evaluations: 890
# -------------------
# Number of fitness evaluations: 897
# -------------------
# Number of fitness evaluations: 904
# -------------------
# Number of fitness evaluations: 911
# -------------------
# Number of fitness evaluations: 918
# -------------------
# Number of fitness evaluations: 925
# -------------------
# Number of fitness evaluations: 932
# -------------------
# Number of fitness evaluations: 939
# -------------------
# Number of fitness evaluations: 946
# -------------------
# Number of fitness evaluations: 953
# -------------------
# Number of fitness evaluations: 960
# -------------------
# Number of fitness evaluations: 967
# -------------------
# Number of fitness evaluations: 974
# -------------------
# Number of fitness evaluations: 981
# -------------------
# Number of fitness evaluations: 988
# -------------------
# Number of fitness evaluations: 995
# -------------------
# Number of fitness evaluations: 1002
# -------------------
# Number of fitness evaluations: 1009
# -------------------
# Number of fitness evaluations: 1016
# -------------------
# Number of fitness evaluations: 1023
# -------------------
# Number of fitness evaluations: 1030
# -------------------
# Number of fitness evaluations: 1037
# -------------------
# Number of fitness evaluations: 1044
# -------------------
# Number of fitness evaluations: 1051
# -------------------
# Number of fitness evaluations: 1058
# -------------------
# Number of fitness evaluations: 1065
# -------------------
# Number of fitness evaluations: 1072
# -------------------
# Number of fitness evaluations: 1079
# -------------------
# Number of fitness evaluations: 1086
# -------------------
# Number of fitness evaluations: 1093
# -------------------
# Number of fitness evaluations: 1100
# -------------------
# Number of fitness evaluations: 1107
# -------------------
# Number of fitness evaluations: 1114
# -------------------
# Number of fitness evaluations: 1121
# -------------------
# Number of fitness evaluations: 1128
# -------------------
# Number of fitness evaluations: 1135
# -------------------
# Number of fitness evaluations: 1142
# -------------------
# Number of fitness evaluations: 1149
# -------------------
# Number of fitness evaluations: 1156
# -------------------
# Number of fitness evaluations: 1163
# -------------------
# Number of fitness evaluations: 1170
# -------------------
# Number of fitness evaluations: 1177
# -------------------
# Number of fitness evaluations: 1184
# -------------------
# Number of fitness evaluations: 1191
# -------------------
# Number of fitness evaluations: 1198
# -------------------
# Number of fitness evaluations: 1205
# -------------------
# Number of fitness evaluations: 1212
# -------------------
# Number of fitness evaluations: 1219
# -------------------
# Number of fitness evaluations: 1226
# -------------------
# Number of fitness evaluations: 1233
# -------------------
# Number of fitness evaluations: 1240
# -------------------
# Number of fitness evaluations: 1247
# -------------------
# Number of fitness evaluations: 1254
# -------------------
# Number of fitness evaluations: 1261
# -------------------
# Number of fitness evaluations: 1268
# -------------------
# Number of fitness evaluations: 1275
# -------------------
# Number of fitness evaluations: 1282
# -------------------
# Number of fitness evaluations: 1289
# -------------------
# Number of fitness evaluations: 1296
# -------------------
# Number of fitness evaluations: 1303
# -------------------
# Number of fitness evaluations: 1310
# -------------------
# Number of fitness evaluations: 1317
# -------------------
# Number of fitness evaluations: 1324
# -------------------
# Number of fitness evaluations: 1331
# -------------------
# Number of fitness evaluations: 1338
# -------------------
# Number of fitness evaluations: 1345
# -------------------
# Number of fitness evaluations: 1352
# -------------------
# Number of fitness evaluations: 1359
# -------------------
# Number of fitness evaluations: 1366
# -------------------
# Number of fitness evaluations: 1373
# -------------------
# Number of fitness evaluations: 1380
# -------------------
# Number of fitness evaluations: 1387
# -------------------
# Number of fitness evaluations: 1394
# -------------------
# Number of fitness evaluations: 1401
# -------------------
# Number of fitness evaluations: 1408
# -------------------
# Number of fitness evaluations: 1415
# -------------------
# Number of fitness evaluations: 1422
# -------------------
# Number of fitness evaluations: 1429
# -------------------
# Number of fitness evaluations: 1436
# -------------------
# Number of fitness evaluations: 1443
# -------------------
# Number of fitness evaluations: 1450
# -------------------
# Number of fitness evaluations: 1457
# -------------------
# Number of fitness evaluations: 1464
# -------------------
# Number of fitness evaluations: 1471
# -------------------
# Number of fitness evaluations: 1478
# -------------------
# Number of fitness evaluations: 1485
# -------------------
# Number of fitness evaluations: 1492
# -------------------
# Number of fitness evaluations: 1499
# -------------------
# Number of fitness evaluations: 1506
# -------------------
# Number of fitness evaluations: 1513
# -------------------
# Number of fitness evaluations: 1520
# -------------------
# Number of fitness evaluations: 1527
# -------------------
# Number of fitness evaluations: 1534
# -------------------
# Number of fitness evaluations: 1541
# -------------------
# Number of fitness evaluations: 1548
# -------------------
# Number of fitness evaluations: 1555
# -------------------
# Number of fitness evaluations: 1562
# -------------------
# Number of fitness evaluations: 1569
# -------------------
# Number of fitness evaluations: 1576
# -------------------
# Number of fitness evaluations: 1583
# -------------------
# Number of fitness evaluations: 1590
# -------------------
# Number of fitness evaluations: 1597
# -------------------
# Number of fitness evaluations: 1604
# -------------------
# Number of fitness evaluations: 1611
# -------------------
# Number of fitness evaluations: 1618
# -------------------
# Number of fitness evaluations: 1625
# -------------------
# Number of fitness evaluations: 1632
# -------------------
# Number of fitness evaluations: 1639
# -------------------
# Number of fitness evaluations: 1646
# -------------------
# Number of fitness evaluations: 1653
# -------------------
# Number of fitness evaluations: 1660
# -------------------
# Number of fitness evaluations: 1667
# -------------------
# Number of fitness evaluations: 1674
# -------------------
# Number of fitness evaluations: 1681
# -------------------
# Number of fitness evaluations: 1688
# -------------------
# Number of fitness evaluations: 1695
# -------------------
# Number of fitness evaluations: 1702
# -------------------
# Number of fitness evaluations: 1709
# -------------------
# Number of fitness evaluations: 1716
# -------------------
# Number of fitness evaluations: 1723
# -------------------
# Number of fitness evaluations: 1730
# -------------------
# Number of fitness evaluations: 1737
# -------------------
# Number of fitness evaluations: 1744
# -------------------
# Number of fitness evaluations: 1751
# -------------------
# Number of fitness evaluations: 1758
# -------------------
# Number of fitness evaluations: 1765
# -------------------
# Number of fitness evaluations: 1772
# -------------------
# Number of fitness evaluations: 1779
# -------------------
# Number of fitness evaluations: 1786
# -------------------
# Number of fitness evaluations: 1793
# -------------------
# Number of fitness evaluations: 1800
# -------------------
# Number of fitness evaluations: 1807
# -------------------
# Number of fitness evaluations: 1814
# -------------------
# Number of fitness evaluations: 1821
# -------------------
# Number of fitness evaluations: 1828
# -------------------
# Number of fitness evaluations: 1835
# -------------------
# Number of fitness evaluations: 1842
# -------------------
# Number of fitness evaluations: 1849
# -------------------
# Number of fitness evaluations: 1856
# -------------------
# Number of fitness evaluations: 1863
# -------------------
# Number of fitness evaluations: 1870
# -------------------
# Number of fitness evaluations: 1877
# -------------------
# Number of fitness evaluations: 1884
# -------------------
# Number of fitness evaluations: 1891
# -------------------
# Number of fitness evaluations: 1898
# -------------------
# Number of fitness evaluations: 1905
# -------------------
# Number of fitness evaluations: 1912
# -------------------
# Number of fitness evaluations: 1919
# -------------------
# Number of fitness evaluations: 1926
# -------------------
# Number of fitness evaluations: 1933
# -------------------
# Number of fitness evaluations: 1940
# -------------------
# Number of fitness evaluations: 1947
# -------------------
# Number of fitness evaluations: 1954
# -------------------
# Number of fitness evaluations: 1961
# -------------------
# Number of fitness evaluations: 1968
# -------------------
# Number of fitness evaluations: 1975
# -------------------
# Number of fitness evaluations: 1982
# -------------------
# Number of fitness evaluations: 1989
# -------------------
# Number of fitness evaluations: 1996
# -------------------
# Number of fitness evaluations: 2003
# -------------------
# Best Tree
# *
# |M
# |-4.5
# (1333,
#  ['35',
#   '20',
#   'm 0 19',
#   '0 34 0',
#   '1 34 0',
#   '2 34 0',
#   'w 0 5',
#   'w 0 6',
#   'w 0 7',
#   'w 0 8',
#   'w 1 1',
#   'w 1 2',
#   'w 1 3',
#   'w 1 10',
#   'w 1 11',
#   'w 1 12',
#   'w 1 13',
#   'w 1 15',
#   'w 1 17',
#   'w 1 18',
#   'w 2 1',
#   'w 2 5',
#   'w 2 6',
#   'w 2 7',
#   'w 2 8',
#   'w 2 13',
#   'w 2 15',
#   'w 2 17',
#   'w 2 18',
#   'w 3 1',
#   'w 3 3',
#   'w 3 4',
#   'w 3 5',
#   'w 3 6',
#   'w 3 7',
#   'w 3 8',
#   'w 3 9',
#   'w 3 10',
#   'w 3 11',
#   'w 3 13',
#   'w 3 17',
#   'w 3 18',
#   'w 4 3',
#   'w 4 4',
#   'w 4 5',
#   'w 4 6',
#   'w 4 7',
#   'w 4 8',
#   'w 4 9',
#   'w 4 10',
#   'w 4 11',
#   'w 4 15',
#   'w 5 1',
#   'w 5 2',
#   'w 5 3',
#   'w 5 4',
#   'w 5 5',
#   'w 5 6',
#   'w 5 7',
#   'w 5 8',
#   'w 5 9',
#   'w 5 10',
#   'w 5 11',
#   'w 5 12',
#   'w 5 14',
#   'w 5 15',
#   'w 5 16',
#   'w 5 18',
#   'w 6 3',
#   'w 6 4',
#   'w 6 5',
#   'w 6 6',
#   'w 6 7',
#   'w 6 8',
#   'w 6 9',
#   'w 6 10',
#   'w 6 11',
#   'w 6 12',
#   'w 6 14',
#   'w 6 15',
#   'w 6 16',
#   'w 6 18',
#   'w 7 1',
#   'w 7 3',
#   'w 7 4',
#   'w 7 5',
#   'w 7 6',
#   'w 7 7',
#   'w 7 8',
#   'w 7 9',
#   'w 7 14',
#   'w 7 15',
#   'w 7 16',
#   'w 8 3',
#   'w 8 4',
#   'w 8 5',
#   'w 8 6',
#   'w 8 7',
#   'w 8 8',
#   'w 8 9',
#   'w 8 11',
#   'w 8 12',
#   'w 8 13',
#   'w 8 14',
#   'w 8 15',
#   'w 8 16',
#   'w 8 18',
#   'w 9 0',
#   'w 9 2',
#   'w 9 3',
#   'w 9 4',
#   'w 9 5',
#   'w 9 6',
#   'w 9 7',
#   'w 9 8',
#   'w 9 9',
#   'w 9 11',
#   'w 9 12',
#   'w 9 13',
#   'w 9 14',
#   'w 9 15',
#   'w 9 16',
#   'w 10 0',
#   'w 10 2',
#   'w 10 3',
#   'w 10 4',
#   'w 10 5',
#   'w 10 6',
#   'w 10 7',
#   'w 10 8',
#   'w 10 9',
#   'w 10 11',
#   'w 10 12',
#   'w 10 13',
#   'w 10 14',
#   'w 10 15',
#   'w 10 16',
#   'w 10 17',
#   'w 10 18',
#   'w 11 0',
#   'w 11 2',
#   'w 11 3',
#   'w 11 4',
#   'w 11 5',
#   'w 11 6',
#   'w 11 7',
#   'w 11 8',
#   'w 11 9',
#   'w 11 11',
#   'w 11 12',
#   'w 11 13',
#   'w 11 14',
#   'w 11 15',
#   'w 11 16',
#   'w 11 17',
#   'w 11 18',
#   'w 12 2',
#   'w 12 3',
#   'w 12 4',
#   'w 12 5',
#   'w 12 11',
#   'w 12 12',
#   'w 12 13',
#   'w 12 14',
#   'w 12 15',
#   'w 12 16',
#   'w 12 17',
#   'w 12 18',
#   'w 13 1',
#   'w 13 2',
#   'w 13 3',
#   'w 13 4',
#   'w 13 5',
#   'w 13 7',
#   'w 13 8',
#   'w 13 9',
#   'w 14 1',
#   'w 14 2',
#   'w 14 3',
#   'w 14 4',
#   'w 14 5',
#   'w 14 7',
#   'w 14 8',
#   'w 14 9',
#   'w 14 11',
#   'w 14 13',
#   'w 14 14',
#   'w 14 15',
#   'w 14 16',
#   'w 14 17',
#   'w 14 18',
#   'w 15 7',
#   'w 15 8',
#   'w 15 9',
#   'w 15 11',
#   'w 16 1',
#   'w 16 2',
#   'w 16 3',
#   'w 16 4',
#   'w 16 13',
#   'w 16 14',
#   'w 16 15',
#   'w 16 17',
#   'w 16 18',
#   'w 16 19',
#   'w 17 1',
#   'w 17 2',
#   'w 17 3',
#   'w 17 4',
#   'w 17 6',
#   'w 17 7',
#   'w 17 8',
#   'w 17 9',
#   'w 17 10',
#   'w 17 11',
#   'w 17 13',
#   'w 17 14',
#   'w 17 15',
#   'w 17 17',
#   'w 17 18',
#   'w 17 19',
#   'w 18 1',
#   'w 18 2',
#   'w 18 3',
#   'w 18 4',
#   'w 18 13',
#   'w 18 14',
#   'w 18 15',
#   'w 18 17',
#   'w 18 18',
#   'w 18 19',
#   'w 19 7',
#   'w 19 8',
#   'w 19 9',
#   'w 19 11',
#   'w 20 1',
#   'w 20 2',
#   'w 20 3',
#   'w 20 4',
#   'w 20 5',
#   'w 20 7',
#   'w 20 8',
#   'w 20 9',
#   'w 20 11',
#   'w 20 13',
#   'w 20 14',
#   'w 20 15',
#   'w 20 16',
#   'w 20 17',
#   'w 20 18',
#   'w 21 1',
#   'w 21 2',
#   'w 21 3',
#   'w 21 4',
#   'w 21 5',
#   'w 21 7',
#   'w 21 8',
#   'w 21 9',
#   'w 22 2',
#   'w 22 3',
#   'w 22 4',
#   'w 22 5',
#   'w 22 11',
#   'w 22 12',
#   'w 22 13',
#   'w 22 14',
#   'w 22 15',
#   'w 22 16',
#   'w 22 17',
#   'w 22 18',
#   'w 23 0',
#   'w 23 2',
#   'w 23 3',
#   'w 23 4',
#   'w 23 5',
#   'w 23 6',
#   'w 23 7',
#   'w 23 8',
#   'w 23 9',
#   'w 23 11',
#   'w 23 12',
#   'w 23 13',
#   'w 23 14',
#   'w 23 15',
#   'w 23 16',
#   'w 23 17',
#   'w 23 18',
#   'w 24 0',
#   'w 24 2',
#   'w 24 3',
#   'w 24 4',
#   'w 24 5',
#   'w 24 6',
#   'w 24 7',
#   'w 24 8',
#   'w 24 9',
#   'w 24 11',
#   'w 24 12',
#   'w 24 13',
#   'w 24 14',
#   'w 24 15',
#   'w 24 16',
#   'w 24 17',
#   'w 24 18',
#   'w 25 0',
#   'w 25 2',
#   'w 25 3',
#   'w 25 4',
#   'w 25 5',
#   'w 25 6',
#   'w 25 7',
#   'w 25 8',
#   'w 25 9',
#   'w 25 11',
#   'w 25 12',
#   'w 25 13',
#   'w 25 14',
#   'w 25 15',
#   'w 25 16',
#   'w 26 3',
#   'w 26 4',
#   'w 26 5',
#   'w 26 6',
#   'w 26 7',
#   'w 26 8',
#   'w 26 9',
#   'w 26 11',
#   'w 26 12',
#   'w 26 13',
#   'w 26 14',
#   'w 26 15',
#   'w 26 16',
#   'w 26 18',
#   'w 27 1',
#   'w 27 3',
#   'w 27 4',
#   'w 27 5',
#   'w 27 6',
#   'w 27 7',
#   'w 27 8',
#   'w 27 9',
#   'w 27 14',
#   'w 27 15',
#   'w 27 16',
#   'w 28 3',
#   'w 28 4',
#   'w 28 5',
#   'w 28 6',
#   'w 28 7',
#   'w 28 8',
#   'w 28 9',
#   'w 28 10',
#   'w 28 11',
#   'w 28 12',
#   'w 28 14',
#   'w 28 15',
#   'w 28 16',
#   'w 28 18',
#   'w 29 1',
#   'w 29 2',
#   'w 29 3',
#   'w 29 4',
#   'w 29 5',
#   'w 29 6',
#   'w 29 7',
#   'w 29 8',
#   'w 29 9',
#   'w 29 10',
#   'w 29 11',
#   'w 29 12',
#   'w 29 14',
#   'w 29 15',
#   'w 29 16',
#   'w 29 18',
#   'w 30 3',
#   'w 30 4',
#   'w 30 5',
#   'w 30 6',
#   'w 30 7',
#   'w 30 8',
#   'w 30 9',
#   'w 30 10',
#   'w 30 11',
#   'w 30 15',
#   'w 31 1',
#   'w 31 3',
#   'w 31 4',
#   'w 31 5',
#   'w 31 6',
#   'w 31 7',
#   'w 31 8',
#   'w 31 9',
#   'w 31 10',
#   'w 31 11',
#   'w 31 13',
#   'w 31 17',
#   'w 31 18',
#   'w 32 1',
#   'w 32 5',
#   'w 32 6',
#   'w 32 7',
#   'w 32 8',
#   'w 32 13',
#   'w 32 15',
#   'w 32 17',
#   'w 32 18',
#   'w 33 1',
#   'w 33 2',
#   'w 33 3',
#   'w 33 10',
#   'w 33 11',
#   'w 33 12',
#   'w 33 13',
#   'w 33 15',
#   'w 33 17',
#   'w 33 18',
#   'w 34 5',
#   'w 34 6',
#   'w 34 7',
#   'w 34 8',
#   'p 0 0',
#   'p 21 13',
#   'p 17 0',
#   'p 34 16',
#   'p 1 8',
#   'p 19 6',
#   'p 24 19',
#   'p 30 19',
#   'p 6 13',
#   'p 15 6',
#   'p 27 19',
#   'p 9 17',
#   'p 3 15',
#   'p 13 11',
#   'p 33 4',
#   't 1400 0',
#   'm 0 19',
#   '0 34 1',
#   '1 34 1',
#   '2 34 1',
#   't 1399 0',
#   'm 0 19',
#   '0 34 2',
#   '1 34 2',
#   '2 34 2',
#   't 1398 0',
#   'm 1 19',
#   '0 34 3',
#   '1 34 3',
#   '2 34 3',
#   't 1397 0',
#   'm 0 19',
#   '0 34 4',
#   '1 34 4',
#   '2 34 4',
#   't 1396 0',
#   'm 0 19',
#   '0 33 4',
#   '1 33 4',
#   '2 33 4',
#   't 1395 0',
#   'm 0 19',
#   '0 33 5',
#   '1 33 5',
#   '2 33 5',
#   't 1394 0',
#   'm 1 19',
#   '0 33 6',
#   '1 33 6',
#   '2 33 6',
#   't 1393 0',
#   'm 1 19',
#   '0 33 7',
#   '1 33 7',
#   '2 33 7',
#   't 1392 0',
#   'm 2 19',
#   '0 33 8',
#   '1 33 8',
#   '2 33 8',
#   't 1391 0',
#   'm 2 19',
#   '0 33 9',
#   '1 33 9',
#   '2 33 9',
#   'f 2 12',
#   't 1390 0',
#   'm 2 19',
#   '0 32 9',
#   '1 32 9',
#   '2 32 9',
#   't 1389 0',
#   'm 2 19',
#   '0 32 10',
#   '1 32 10',
#   '2 32 10',
#   't 1388 0',
#   'm 2 19',
#   '0 32 11',
#   '1 32 11',
#   '2 32 11',
#   't 1387 0',
#   'm 1 19',
#   '0 32 12',
#   '1 32 12',
#   '2 32 12',
#   't 1386 0',
#   'm 2 19',
#   '0 31 12',
#   '1 31 12',
#   '2 31 12',
#   't 1385 0',
#   'm 1 19',
#   '0 30 12',
#   '1 30 12',
#   '2 30 12',
#   't 1384 0',
#   'm 1 19',
#   '0 30 13',
#   '1 30 13',
#   '2 30 13',
#   't 1383 0',
#   'm 1 19',
#   '0 30 14',
#   '1 30 14',
#   '2 30 14',
#   't 1382 0',
#   'm 1 19',
#   '0 31 14',
#   '1 31 14',
#   '2 31 14',
#   't 1381 0',
#   'm 0 19',
#   '0 31 15',
#   '1 31 15',
#   '2 31 15',
#   't 1380 0',
#   'm 1 19',
#   '0 31 16',
#   '1 31 16',
#   '2 31 16',
#   't 1379 0',
#   'm 0 19',
#   '0 30 16',
#   '1 30 16',
#   '2 30 16',
#   't 1378 0',
#   'm 1 19',
#   '0 30 17',
#   '1 30 17',
#   '2 30 17',
#   't 1377 0',
#   'm 1 19',
#   '0 30 18',
#   '1 30 18',
#   '2 30 18',
#   't 1376 0',
#   'm 2 19',
#   '0 30 19',
#   '1 30 19',
#   '2 30 19',
#   't 1375 0',
#   'm 1 19',
#   '0 29 19',
#   '1 29 19',
#   '2 29 19',
#   't 1374 0',
#   'm 2 19',
#   '0 28 19',
#   '1 28 19',
#   '2 28 19',
#   't 1373 0',
#   'm 1 19',
#   '0 27 19',
#   '1 27 19',
#   '2 27 19',
#   't 1372 0',
#   'm 2 19',
#   '0 26 19',
#   '1 26 19',
#   '2 26 19',
#   't 1371 0',
#   'm 2 19',
#   '0 25 19',
#   '1 25 19',
#   '2 25 19',
#   't 1370 0',
#   'm 3 19',
#   '0 24 19',
#   '1 24 19',
#   '2 24 19',
#   't 1369 0',
#   'm 2 19',
#   '0 23 19',
#   '1 23 19',
#   '2 23 19',
#   't 1368 0',
#   'm 2 19',
#   '0 22 19',
#   '1 22 19',
#   '2 22 19',
#   't 1367 0',
#   'm 2 19',
#   '0 21 19',
#   '1 21 19',
#   '2 21 19',
#   't 1366 0',
#   'm 3 19',
#   '0 20 19',
#   '1 20 19',
#   '2 20 19',
#   't 1365 0',
#   'm 4 19',
#   '0 19 19',
#   '1 19 19',
#   '2 19 19',
#   't 1364 0',
#   'm 4 18',
#   '0 20 19',
#   '1 20 19',
#   '2 20 19',
#   't 1363 0',
#   'm 4 17',
#   '0 19 19',
#   '1 19 19',
#   '2 19 19',
#   't 1362 0',
#   'm 4 16',
#   '0 19 18',
#   '1 19 18',
#   '2 19 18',
#   't 1361 0',
#   'm 4 16',
#   '0 19 17',
#   '1 19 17',
#   '2 19 17',
#   't 1360 0',
#   'm 4 16',
#   '0 19 16',
#   '1 19 16',
#   '2 19 16',
#   't 1359 0',
#   'm 4 17',
#   '0 18 16',
#   '1 18 16',
#   '2 18 16',
#   't 1358 0',
#   'm 5 17',
#   '0 17 16',
#   '1 17 16',
#   '2 17 16',
#   't 1357 0',
#   'm 4 17',
#   '0 16 16',
#   '1 16 16',
#   '2 16 16',
#   't 1356 0',
#   'm 4 18',
#   '0 15 16',
#   '1 15 16',
#   '2 15 16',
#   't 1355 0',
#   'm 4 19',
#   '0 15 17',
#   '1 15 17',
#   '2 15 17',
#   't 1354 0',
#   'm 3 19',
#   '0 15 18',
#   '1 15 18',
#   '2 15 18',
#   't 1353 0',
#   'm 3 19',
#   '0 15 19',
#   '1 15 19',
#   '2 15 19',
#   't 1352 0',
#   'm 4 19',
#   '0 14 19',
#   '1 14 19',
#   '2 14 19',
#   't 1351 0',
#   'm 4 19',
#   '0 13 19',
#   '1 13 19',
#   '2 13 19',
#   't 1350 0',
#   'm 5 19',
#   '0 12 19',
#   '1 12 19',
#   '2 12 19',
#   't 1349 0',
#   'm 5 19',
#   '0 11 19',
#   '1 11 19',
#   '2 11 19',
#   't 1348 0',
#   'm 4 19',
#   '0 10 19',
#   '1 10 19',
#   '2 10 19',
#   't 1347 0',
#   'm 4 18',
#   '0 9 19',
#   '1 9 19',
#   '2 9 19',
#   't 1346 0',
#   'm 4 19',
#   '0 9 18',
#   '1 9 18',
#   '2 9 18',
#   't 1345 0',
#   'm 3 19',
#   '0 9 19',
#   '1 9 19',
#   '2 9 19',
#   't 1344 0',
#   'm 2 19',
#   '0 8 19',
#   '1 8 19',
#   '2 8 19',
#   't 1343 0',
#   'm 2 19',
#   '0 7 19',
#   '1 7 19',
#   '2 7 19',
#   't 1342 0',
#   'm 3 19',
#   '0 6 19',
#   '1 6 19',
#   '2 6 19',
#   't 1341 0',
#   'm 2 19',
#   '0 5 19',
#   '1 5 19',
#   '2 5 19',
#   't 1340 0',
#   'm 3 19',
#   '0 4 19',
#   '1 4 19',
#   '2 4 19',
#   't 1339 0',
#   'm 2 19',
#   '0 3 19',
#   '1 3 19',
#   '2 3 19',
#   't 1338 0',
#   'm 3 19',
#   '0 2 19',
#   '1 2 19',
#   '2 2 19',
#   't 1337 0'],
#  <ghost_tree_genotype.GhostTreeGenotype at 0x7f89c0368550>,
#  369.4867142857143,
#  1014.675)

# %% [markdown]
# ### Red 3 Full Run

# %%
number_runs = 30
number_evaluations = 2000
config_filename = './configs/red3_2b_config.txt'

runsData = list()

for runCount in range(number_runs):
    print(f'Run # {runCount}')
    runsData.append(ghost_genetic_programming_search(number_evaluations, config_filename, runCount))
    
runsDataBestFitnesses = [runData[0] for runData in runsData]
overallBestFitness = max(runsDataBestFitnesses)

runsDataBestRawFitnesses = [runData[2].raw_fitness for runData in runsData]
          
runsDataBestLogs = [runData[1] for runData in runsData]
overallBestLog = runsDataBestLogs[runsDataBestFitnesses.index(overallBestFitness)]
          
runsDataBestTrees = [runData[2] for runData in runsData]
overallBestTree = runsDataBestTrees[runsDataBestFitnesses.index(overallBestFitness)]

runsDataAveFitnesses = [runData[3] for runData in runsData]
runsDataAveBestFitnesses = [runData[4] for runData in runsData]

print(f'Overall Best Fitness(penalized): {overallBestFitness}')

game_log_path = 'worldFiles/overallBestRed3.txt'
with open(game_log_path, 'w') as f:
    [f.write(f'{line}\n') for line in overallBestLog]
          
print('Best Tree')
#print(overallBestTree.print())
with open(f'solutions/bestRed3Tree.txt','w') as f:
    f.write(overallBestTree.print())

with open('./data/redThree/bestRawFitnesses.txt', 'w') as fp:
    for fitness in runsDataBestRawFitnesses:
        fp.write(f'{fitness}\n')

plt.figure()
plt.title(f'Mult-run experiement best and average fitnesses (Multiple Identical Ghost Controllers)')
plt.xlabel('Runs')
plt.ylabel('Fitness')
plt.plot(range(number_runs), runsDataAveBestFitnesses, label="Average Best Fitness")
plt.plot(range(number_runs), runsDataAveFitnesses, label="Average Fitness")
plt.legend(loc="upper right")
# Out:
# Run # 0
# Run # 1
# Run # 2
# Run # 3
# Run # 4
# Run # 5
# Run # 6
# Run # 7
# Run # 8
# Run # 9
# Run # 10
# Run # 11
# Run # 12
# Run # 13
# Run # 14
# Run # 15
# Run # 16
# Run # 17
# Run # 18
# Run # 19
# Run # 20
# Run # 21
# Run # 22
# Run # 23
# Run # 24
# Run # 25
# Run # 26
# Run # 27
# Run # 28
# Run # 29
# Overall Best Fitness(penalized): 1338
# Best Tree

# %% [markdown]
# # Side Note: Canonical Genetic Programming
#
# Should you apply GP after this class, you should know that the GP algorithm taught in this class (as described in the course textbook) differs somewhat from the algorithm canonically used in GP. Notably, the textbook has certain important omissions regarding the Ramped Half-and-half algorithm and the GP evolutionary cycle. In practice, the Ramped Half-and-half algorithm uses a `grow` method which ensures at least 1 branch reaches the depth limit. This can be difficult to implement, and has little impact on this assignment, so we don't require the implementation of the canonical version of the algorithm.
#
# More importantly, however, is that the canonical GP evolutionary cycle is generational in nature. In the canonical Generational GP algorithm, $\mu$ children are created each generation via recombination, mutation, or *reproduction* and the children directly replace the parents without survival selection. Notably, the reproduction operation involves directly copying the selected parent to the children pool and this enables behavior similar to steady state survival. The algorithm you implement for this assignment series is much more similar to a Genetic Algorithm in nature and you should be aware of this distinction if you continue to work with GP. For more information see [here](https://geneticprogramming.com/about-gp/gp-workflow/).
